# %% [markdown]
# You practice the follwoing functions using different datasets:
#     melt(), pivot(), pivot_table()
#     Correlation matrixâ€‹
#     scatter_matrix
#     profile_report
#     outliers

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("files/world_population.csv")
df

# %% [markdown]
# Reshape the dataframe using melt() in which id_vars is "Country"], value_vars is "Continent" and value_name is "Continent_names".

# %%
# Up to you!

# %% [markdown]
# Save the resulted dataframe in "melted_pets" dataframe.

# %% [markdown]
# Filter the dataframe using df["Continent"] == "Europe"
# Use pivot() to reshape the filtered dataframe in which index is "Country", columns is "Continent", and shows the value of "=""2022 Population".
# Filter the dataframe using df["Continent"] == "Asia" and with the above conditions.

# %%
# Up to you!

# %%
# Up to you!

# %% [markdown]
# Show Correlation matrix of "student.xls" using cmap ='seismic'
# Use Pandas Profiling Report to explore student data from basic analysis aspect.

# %%
# Up to you!

# %% [markdown]
# Plot the scatter_matrix of "datasauRus.csv" file with x<20.

# %%
# Up to you!

# %%
from pandas_profiling import profile_report
df_student.profile_report()

# %% [markdown]
# 1- Set the first 1000 samples(rows) of "train.csv" in a df_part dataframe
# 2- Plot the scatter plot with x='breath_id',y='pressure'

# %%
# Up to you!

# %% [markdown]
# Plot the 'pressure' column of df_part using boxplot.

# %%
# Up to you!

# %% [markdown]
# Find the outlier using a the outlier function that you learned from the slides. Check the number of outliers.

# %%
# Up to you!

# %% [markdown]
# Remove the outliers from the df_part and plot it using a boxplot.

# %%
# Up to you!

# %% [markdown]
# Plot the outliers using a boxplot.

# %%
outliers.boxplot(column=['pressure'])
outliers.shape
