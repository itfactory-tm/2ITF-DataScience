# %% [markdown]
# # Flights
#
# Enclosed is a CSV-file of all [flights out of NYC in 2013](https://github.com/tidyverse/nycflights13). We'll be doing a bunch of selections and cleaning on this dataset.
#
# We don't have a CSV-file for you this time, but we have a package. Install it and you're good to go!

# %%
# !pip install --upgrade setuptools
# !pip install nycflights13

# %%
from nycflights13 import flights

flights[0:5]

# %% [markdown]
# It's a big dataset, 300.000 observations over 19 variables.
#
# Now show all flights from April (the fields year, month, day, origin and dest).

# %%
# Up to you!

# %% [markdown]
# Now only the 5th of April...

# %%
# Up to you!

# %% [markdown]
# The fifth day, but in June **or** July.

# %%
# Up to you!

# %% [markdown]
# Same as above, but sort by destination.

# %%
# Up to you!

# %% [markdown]
# Add a column speed. This column can be calculated from "distance" and "air_time". (Distance is in miles, air_time in minutes. These need to be converted to km and hours.)
#
# <code>speed = distance * 1.6093 / air_time * 60</code>

# %%
# Up to you!

# %% [markdown]
# What is the average of the three above columns?

# %%
# Up to you!

# %% [markdown]
# Describe all fields in our dataset.

# %%
# Up to you!

# %% [markdown]
# Get the average delay per month.

# %%
# Up to you!
