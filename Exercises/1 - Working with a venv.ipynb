# %% [markdown]
# # Working with a venv
#
# This notebook helps you install all the libraries we need in the virtual environment that you created when you followed the powerpoint called '1bis Setting up your working environment'.
#
# You can install all libraries one by one. Let's do that with numpy:

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (1.26.1)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Note how the command started with an exclamation mark. This means it's run as a terminal command and not as a Python-command. As an alternative you can use a percentage (which is quite different internally, but has the same effect).
#
# You'll find these type of code block regularly on top of other notebooks. Usually they are commented out because they take up a lot of time when running the full notebook and should only be run once anyways.
#
# There is another way of installing a lot of libraries at once: a requirements.txt file. You import the one we are using the following code-block. (Note: this will take a while. Just let it run.)

# %%
# !pip install -r files/requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.4.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: backcall==0.2.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: comm==0.1.4 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: contourpy==1.1.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: cycler==0.12.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: decorator==5.1.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: executing==2.0.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: fonttools==4.43.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 10)) (4.43.1)
# Requirement already satisfied: ipykernel==6.25.2 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 11)) (6.25.2)
# Requirement already satisfied: ipython==8.16.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 12)) (8.16.1)
# Requirement already satisfied: jedi==0.19.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 13)) (0.19.1)
# Requirement already satisfied: jupyter_client==8.4.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 14)) (8.4.0)
# Requirement already satisfied: jupyter_core==5.4.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 15)) (5.4.0)
# Requirement already satisfied: kiwisolver==1.4.5 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 16)) (1.4.5)
# Requirement already satisfied: matplotlib==3.8.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 17)) (3.8.0)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 18)) (0.1.6)
# Requirement already satisfied: nest-asyncio==1.5.8 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 19)) (1.5.8)
# Requirement already satisfied: numpy==1.26.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 20)) (1.26.1)
# Requirement already satisfied: packaging==23.2 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 21)) (23.2)
# Requirement already satisfied: pandas==2.1.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 22)) (2.1.1)
# Requirement already satisfied: parso==0.8.3 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 23)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 24)) (0.7.5)
# Requirement already satisfied: Pillow==10.1.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 25)) (10.1.0)
# Requirement already satisfied: platformdirs==3.11.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 26)) (3.11.0)
# Requirement already satisfied: prompt-toolkit==3.0.39 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 27)) (3.0.39)
# Requirement already satisfied: psutil==5.9.6 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 28)) (5.9.6)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 29)) (0.2.2)
# Requirement already satisfied: Pygments==2.16.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 30)) (2.16.1)
# Requirement already satisfied: pyparsing==3.1.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 31)) (3.1.1)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 32)) (2.8.2)
# Requirement already satisfied: pytz==2023.3.post1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 33)) (2023.3.post1)
# Requirement already satisfied: pywin32==306 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 34)) (306)
# Requirement already satisfied: pyzmq==25.1.1 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 35)) (25.1.1)
# Requirement already satisfied: seaborn==0.13.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 36)) (0.13.0)
# Requirement already satisfied: six==1.16.0 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 37)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 38)) (0.6.3)
# Requirement already satisfied: tornado==6.3.3 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 39)) (6.3.3)
# Requirement already satisfied: traitlets==5.11.2 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 40)) (5.11.2)
# Requirement already satisfied: tzdata==2023.3 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 41)) (2023.3)
# Requirement already satisfied: wcwidth==0.2.8 in c:\users\jochen\onedrive - thomas more\_vakken\data science\data_science_2023\venv\lib\site-packages (from -r files/requirements.txt (line 42)) (0.2.8)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# If all went well (there is a lot of "succesfully installed" at the bottom) you now have a fully installed virtual environment.
#
# You might wonder how we made that file. Well, we used the following code:

# %%
# !pip freeze > files/requirements.txt
