# %% [markdown]
# # Kaggle
#
# As mentioned in the slides, make the following exercises on kaggle:
#
# - [lesson 1: creating reading and writing](https://www.kaggle.com/code/residentmario/creating-reading-and-writing)
# - [lesson 2: indexing selecting assigning](https://www.kaggle.com/code/residentmario/indexing-selecting-assigning)
# - [lesson 4: Grouping and sorting](https://www.kaggle.com/code/residentmario/grouping-and-sorting)
# - [lesson 5: data types and missing values](https://www.kaggle.com/code/residentmario/data-types-and-missing-values)

# %%
# code online!
